# %%
menu ={
    'Pizza':40,
    'Burger':50,
    'Pazzta':60,
    'Tea':30,
    'Coffee':30,
    'Cake':45,
}
print('Welcome to Coffee Lover')
print('Pizza:40\nBurger:50\nPazzta:60\nTea:30\nCoffee:30\nCake:45')
item_1 =input("Enter your order: ")
total_order=0
if item_1 in menu:
    total_order +=menu[item_1]
    print("Your order has been added")
    print(f"Your total amount is {total_order}")
else:
    print("your order is not available")  
another_order=input('Do you want to take another order?(Yes/No)')

if another_order == 'Yes':
    item_2=input('Enter your order: ')
    if item_2 in menu:
       total_order+=menu[item_2]
       print("Your order has been added")
       print(f"Your total amount is {total_order}")
    else:
       print('Your order is not available')
else:
    print(f'Your total amount is {total_order}')
# Out:
# Welcome to our Cafe
# Pizza:40
# Burger:50
# Pazzta:60
# Tea:30
# Coffee:30
# Cake:45
# Your order has been added
# Your total amount is 30
# Your order has been added
# Your total amount is 60
